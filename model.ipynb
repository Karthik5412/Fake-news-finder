# %%
import pandas as pd
import numpy as np
import warnings 

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('D:\\nlp models\\fake news\\evaluation.csv', sep=(';'))
df
# Out:
#       Unnamed: 0                                              title  \
# 0              0  Sanders back in U.S. Senate, blasts 'coloniali...
# 1              1  Kremlin: Syria peoples' congress being 'active...
# 2              2   Oregon Cop Convicted Of Shattering Biker’s Co...
# 3              3   Twitter Erupts With Glee Over #CruzSexScandal...
# 4              4  MUST WATCH VIDEO: Obama Tries To Trash Trump B...
# ...          ...                                                ...
# 8112        8112   Sean Hannity Throws Hissy Fit After Real Repo...
# 8113        8113  FORMER ASST FBI DIRECTOR WARNS ANTI-TRUMP KABA...
# 8114        8114   John McCain: Trump’s Attacks On The Press Are...
# 8115        8115  Syria's Deir al-Zor air base working again: st...
# 8116        8116  U.S. military releases, withdraws old Islamist...
#
#                                                    text  label
# 0     WASHINGTON (Reuters) - Democratic U.S. preside...      1
# ...

# %%
df = df.drop(columns= 'Unnamed: 0')
df
# Out:
#                                                   title  \
# 0     Sanders back in U.S. Senate, blasts 'coloniali...
# 1     Kremlin: Syria peoples' congress being 'active...
# 2      Oregon Cop Convicted Of Shattering Biker’s Co...
# 3      Twitter Erupts With Glee Over #CruzSexScandal...
# 4     MUST WATCH VIDEO: Obama Tries To Trash Trump B...
# ...                                                 ...
# 8112   Sean Hannity Throws Hissy Fit After Real Repo...
# 8113  FORMER ASST FBI DIRECTOR WARNS ANTI-TRUMP KABA...
# 8114   John McCain: Trump’s Attacks On The Press Are...
# 8115  Syria's Deir al-Zor air base working again: st...
# 8116  U.S. military releases, withdraws old Islamist...
#
#                                                    text  label
# 0     WASHINGTON (Reuters) - Democratic U.S. preside...      1
# 1     MOSCOW (Reuters) - A proposal to convene a con...      1
# 2     In a baffling fit of rage, an Oregon State Pol...      0
# ...

# %%
# Converting everything into lower case

df['text'] = df['text'].apply(lambda x: x.lower())
df['title'] = df['title'].apply(lambda x: x.lower())
df
# Out:
#                                                   title  \
# 0     sanders back in u.s. senate, blasts 'coloniali...
# 1     kremlin: syria peoples' congress being 'active...
# 2      oregon cop convicted of shattering biker’s co...
# 3      twitter erupts with glee over #cruzsexscandal...
# 4     must watch video: obama tries to trash trump b...
# ...                                                 ...
# 8112   sean hannity throws hissy fit after real repo...
# 8113  former asst fbi director warns anti-trump kaba...
# 8114   john mccain: trump’s attacks on the press are...
# 8115  syria's deir al-zor air base working again: st...
# 8116  u.s. military releases, withdraws old islamist...
#
#                                                    text  label
# 0     washington (reuters) - democratic u.s. preside...      1
# 1     moscow (reuters) - a proposal to convene a con...      1
# 2     in a baffling fit of rage, an oregon state pol...      0
# ...

# %%
df.isna().sum()
# Out:
# title    0
# text     0
# label    0
# dtype: int64

# %%
# Removing punctuations
import string

def remove_punc(txt) :
    return txt.translate(str.maketrans('','',string.punctuation))

df['title'] = df['title'].apply(remove_punc)
df['text'] = df['text'].apply(remove_punc)

# %%
def remove_num(txt):
    new = ''
    for i in txt :
        if not i.isdigit():
            new = new + i
    return new

df['title'] = df['title'].apply(remove_num)
df['text'] = df['text'].apply(remove_num)

# %%
def remove_emoji(txt):
    new = ''
    for i in txt :
        if i.isascii():
            new = new + i
    return new

df['title'] = df['title'].apply(remove_emoji)
df['text'] = df['text'].apply(remove_emoji)

# %%
df
# Out:
#                                                   title  \
# 0     sanders back in us senate blasts colonialism i...
# 1     kremlin syria peoples congress being actively ...
# 2      oregon cop convicted of shattering bikers col...
# 3      twitter erupts with glee over cruzsexscandal ...
# 4     must watch video obama tries to trash trump bu...
# ...                                                 ...
# 8112   sean hannity throws hissy fit after real repo...
# 8113  former asst fbi director warns antitrump kabal...
# 8114   john mccain trumps attacks on the press are h...
# 8115  syrias deir alzor air base working again state...
# 8116  us military releases withdraws old islamist vi...
#
#                                                    text  label
# 0     washington reuters  democratic us presidential...      1
# 1     moscow reuters  a proposal to convene a congre...      1
# 2     in a baffling fit of rage an oregon state poli...      0
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
stopwords = set(stopwords.words('english'))
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def remove(txt) :
    words = txt.split()
    cleaned = []
    for i in words :
        if not i in stopwords :
            cleaned.append(i)
            
    return ' '.join(cleaned)

df['title'] = df['title'].apply(remove)
df['text'] = df['text'].apply(remove)

# %%
# Feature extraction
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

x_data = df['title'] + df['text']
x = x_data.copy()

x = vectorizer.fit_transform(x)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['aa', 'aaa', 'aadhaar', ..., 'zwo', 'zxmgklb', 'zynga'],
#       shape=(90675,), dtype=object)

# %%
x_data
# Out:
# 0       sanders back us senate blasts colonialism puer...
# 1       kremlin syria peoples congress actively discus...
# 2       oregon cop convicted shattering bikers collarb...
# 3       twitter erupts glee cruzsexscandal rumors twee...
# 4       must watch video obama tries trash trump turns...
#                               ...
# 8112    sean hannity throws hissy fit real reporter ca...
# 8113    former asst fbi director warns antitrump kabal...
# 8114    john mccain trumps attacks press dictators get...
# 8115    syrias deir alzor air base working state media...
# 8116    us military releases withdraws old islamist vi...
# Length: 8117, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

tfidf = TfidfVectorizer()
x_data_encoded = tfidf.fit_transform(x_data)

x_train, x_test, y_train, y_test = train_test_split(x_data_encoded, df['label'], test_size= 0.3, random_state= 42)

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

svm = SVC(kernel= 'rbf')
lg = LogisticRegression(max_iter= 1000)
nv = MultinomialNB()

# %%
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
nv.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score

print(f'svm : {accuracy_score(y_pred= svm.predict(x_test), y_true=y_test)}')
print(f'Lg : {accuracy_score(y_pred= lg.predict(x_test), y_true=y_test)}')
print(f'nv : {accuracy_score(y_pred= nv.predict(x_test), y_true=y_test)}')
# Out:
# svm : 0.9605911330049262
# Lg : 0.9540229885057471
# nv : 0.9105090311986864
