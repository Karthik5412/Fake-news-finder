# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import FunctionTransformer
import pandas as pd
import numpy as np

# %%
import nltk
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

# %%
df = pd.read_csv('D:\\nlp models\\fake news\\evaluation.csv', sep=(';'))

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import string

class preprocessing(BaseEstimator,TransformerMixin) :
    def fit(self,x,y=None) :
        return self
    
    def transform(self,x):
        x = str(x).lower()
        x = x.translate(str.maketrans('','',string.punctuation))
        
        text = "".join([i for i in text if not i.isdigit() and i.isascii()])
        
        new = ''
        cleaned = []
        for i in x :
            if not i.isdigit():
                if i.isascii():
                    new = new + i
        for i in new :
            if not i in stopwords :
                cleaned.append(i)
                
        return ' '.join(cleaned)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.svm import SVC

pipe = Pipeline([
    ('Preprocessing ', preprocessing()),
    ('Vectorization ', TfidfVectorizer()),
    ('Classifier', SVC(kernel='rbf'))
])

# %%
from sklearn.model_selection import train_test_split

x = df.copy()
x['data'] = df['title'] + df['text']

x_train, x_test, y_train, y_test = train_test_split(x['data'] , df['label'], test_size= 0.3, random_state= 42)

# %%
xf = x_train.to_frame()
xf.apply(lambda x : x.to_string().lower())
# Out:
# data    3593    gunmen kill two in attack on universit...
# dtype: object

# %%
pipe.fit(x_train.to_frame(),y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 pipe.fit(x_train.to_frame(),y_train)
#
# File d:\nlp models\fake news\env\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File d:\nlp models\fake news\env\Lib\site-packages\sklearn\pipeline.py:613, in Pipeline.fit(self, X, y, **params)
#     606     raise ValueError(
#     607         "The `transform_input` parameter can only be set if metadata "
#     608         "routing is enabled. You can enable metadata routing using "
# ...
